# %% [markdown]
# # Proyecto 3
#
# **Tema:** Resultados Saber 11
#
# |     Nombres      |      Apellidos       |     Login     |  Codigo   |
# | :--------------: | :------------------: | :-----------: | :-------: |
# |     Santiago     | Gonzalez Montealegre | s.gonzalez35  | 202012274 |
# | Juliana Carolina |  Cardenas Barragan   | jc.cardenasb1 | 202011683 |

# %% [markdown]
# ## Modelo - Aprendizaje de Estructura - Puntajes - BIC

# %% [markdown]
# ## Librerías Requeridas

# %%
import pandas as pd
from pgmpy.estimators import HillClimbSearch
from pgmpy.estimators import BicScore
import networkx as nx
import matplotlib.pyplot as plt
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.readwrite import BIFWriter

# %% [markdown]
# ## Carga de Datos

# %%
df = pd.read_csv("../../Data/Transformed/Discrete.csv")

# %%
df.head()
# Out:
#    colegio_rural  colegio_bilingue  colegio_calendario  colegio_privado  \
# 0              0                 0                   1                0
# 1              0                 0                   1                0
# 2              0                 0                   1                0
# 3              1                 0                   1                1
# 4              0                 0                   1                0
#
#    colegio_genero  colegio_jornada  estudiante_genero  familia_estrato  \
# 0               1                2                  0                1
# 1               1                2                  0                1
# 2               1                2                  0                1
# 3               2                5                  0                4
# 4               1                2                  0                1
#
#    madre_educacion  padre_educacion  computador  internet  puntaje  \
# 0                4                2           1         1        5
# 1                3                3           0         0        4
# 2                3                3           0         0        4
# 3                9               10           1         1        7
# 4                2                2           1         1        5
#
#    colegio_mcpio_distinto  presentacion_mcpio_distinto
# 0                       0                            0
# 1                       0                            1
# 2                       0                            1
# 3                       0                            0
# 4                       0                            0

# %% [markdown]
# ## BIC Score

# %% [markdown]
# ### Estimación Estructura

# %%
scoring_method = BicScore(data=df)
esth = HillClimbSearch(data=df)

estimated_model_bic = esth.estimate(
    scoring_method=scoring_method,
    max_indegree=4,
    max_iter=int(1e4)
)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
print(estimated_model_bic)
print(estimated_model_bic.nodes())
print(estimated_model_bic.edges())
# Out:
# DAG with 15 nodes and 50 edges
# ['colegio_rural', 'colegio_bilingue', 'colegio_calendario', 'colegio_privado', 'colegio_genero', 'colegio_jornada', 'estudiante_genero', 'familia_estrato', 'madre_educacion', 'padre_educacion', 'computador', 'internet', 'puntaje', 'colegio_mcpio_distinto', 'presentacion_mcpio_distinto']
# [('colegio_rural', 'presentacion_mcpio_distinto'), ('colegio_rural', 'colegio_privado'), ('colegio_rural', 'colegio_mcpio_distinto'), ('colegio_rural', 'colegio_calendario'), ('colegio_rural', 'colegio_genero'), ('colegio_calendario', 'colegio_bilingue'), ('colegio_privado', 'colegio_jornada'), ('colegio_privado', 'colegio_calendario'), ('colegio_privado', 'presentacion_mcpio_distinto'), ('colegio_privado', 'colegio_mcpio_distinto'), ('colegio_privado', 'estudiante_genero'), ('colegio_genero', 'estudiante_genero'), ('colegio_genero', 'colegio_bilingue'), ('colegio_jornada', 'colegio_genero'), ('colegio_jornada', 'colegio_calendario'), ('colegio_jornada', 'colegio_bilingue'), ('familia_estrato', 'internet'), ('familia_estrato', 'colegio_privado'), ('familia_estrato', 'puntaje'), ('familia_estrato', 'colegio_calendario'), ('familia_estrato', 'computador'), ('familia_estrato', 'colegio_rural'), ('familia_estrato', 'colegio_bilingue'), ('familia_estrato', 'colegio_genero'), ('familia_estrato', 'colegio_mcpio_distinto'), ('madre_educacion', 'familia_estrato'), ('madre_educacion', 'puntaje'), ('madre_educacion', 'internet'), ('madre_educacion', 'colegio_privado'), ('madre_educacion', 'computador'), ('madre_educacion', 'colegio_jornada'), ('madre_educacion', 'colegio_genero'), ('madre_educacion', 'estudiante_genero'), ('padre_educacion', 'madre_educacion'), ('padre_educacion', 'familia_estrato'), ('padre_educacion', 'colegio_rural'), ('padre_educacion', 'internet'), ('padre_educacion', 'computador'), ('computador', 'puntaje'), ('computador', 'colegio_rural'), ('internet', 'computador'), ('internet', 'colegio_rural'), ('internet', 'presentacion_mcpio_distinto'), ('internet', 'puntaje'), ('internet', 'colegio_mcpio_distinto'), ('puntaje', 'colegio_jornada'), ('puntaje', 'colegio_privado'), ('puntaje', 'estudiante_genero'), ('colegio_mcpio_distinto', 'presentacion_mcpio_distinto'), ('presentacion_mcpio_distinto', 'colegio_jornada')]

# %%
nodes = list(estimated_model_bic.nodes())
edges = list(estimated_model_bic.edges())

# Create Graph
G = nx.DiGraph()

# Add Nodes
for node in nodes:
    G.add_node(node)
    
# Add Edges
for edge in edges:
    G.add_edge(edge[0], edge[1])
    
# Draw Graph
pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_size=1000, arrows=True)
plt.show()

# %%
print(scoring_method.score(estimated_model_bic))
# Out:
# -35374985.84768045

# %% [markdown]
# ### Red Bayesiana

# %%
model = BayesianNetwork(estimated_model_bic)
model.fit(data=df, estimator=MaximumLikelihoodEstimator)

# %%
for i in model.nodes():
    print(model.get_cpds(i))
# Out:
# +------------------+-----+---------------------+
# | computador       | ... | computador(1)       |
# +------------------+-----+---------------------+
# | familia_estrato  | ... | familia_estrato(6)  |
# +------------------+-----+---------------------+
# | internet         | ... | internet(1)         |
# +------------------+-----+---------------------+
# | padre_educacion  | ... | padre_educacion(10) |
# +------------------+-----+---------------------+
# | colegio_rural(0) | ... | 0.7942420152946469  |
# +------------------+-----+---------------------+
# | colegio_rural(1) | ... | 0.20575798470535311 |
# +------------------+-----+---------------------+
# +---------------------+-----+-----------------------+
# | colegio_calendario  | ... | colegio_calendario(3) |
# +---------------------+-----+-----------------------+
# | colegio_genero      | ... | colegio_genero(3)     |
# +---------------------+-----+-----------------------+
# | colegio_jornada     | ... | colegio_jornada(6)    |
# +---------------------+-----+-----------------------+
# | familia_estrato     | ... | familia_estrato(6)    |
# +---------------------+-----+-----------------------+
# | colegio_bilingue(0) | ... | 0.5                   |
# +---------------------+-----+-----------------------+
# | colegio_bilingue(1) | ... | 0.5                   |
# +---------------------+-----+-----------------------+
# +-----------------------+-----+--------------------+
# | colegio_jornada       | ... | colegio_jornada(6) |
# +-----------------------+-----+--------------------+
# | colegio_privado       | ... | colegio_privado(1) |
# +-----------------------+-----+--------------------+
# | colegio_rural         | ... | colegio_rural(1)   |
# +-----------------------+-----+--------------------+
# | familia_estrato       | ... | familia_estrato(6) |
# +-----------------------+-----+--------------------+
# | colegio_calendario(1) | ... | 1.0                |
# +-----------------------+-----+--------------------+
# | colegio_calendario(2) | ... | 0.0                |
# +-----------------------+-----+--------------------+
# | colegio_calendario(3) | ... | 0.0                |
# +-----------------------+-----+--------------------+
# +--------------------+-----+---------------------+
# | colegio_rural      | ... | colegio_rural(1)    |
# +--------------------+-----+---------------------+
# | familia_estrato    | ... | familia_estrato(6)  |
# +--------------------+-----+---------------------+
# | madre_educacion    | ... | madre_educacion(10) |
# +--------------------+-----+---------------------+
# | puntaje            | ... | puntaje(10)         |
# +--------------------+-----+---------------------+
# | colegio_privado(0) | ... | 0.0                 |
# +--------------------+-----+---------------------+
# | colegio_privado(1) | ... | 1.0                 |
# +--------------------+-----+---------------------+
# +-------------------+-----+---------------------+
# | colegio_jornada   | ... | colegio_jornada(6)  |
# +-------------------+-----+---------------------+
# | colegio_rural     | ... | colegio_rural(1)    |
# +-------------------+-----+---------------------+
# | familia_estrato   | ... | familia_estrato(6)  |
# +-------------------+-----+---------------------+
# | madre_educacion   | ... | madre_educacion(10) |
# +-------------------+-----+---------------------+
# | colegio_genero(1) | ... | 0.3333333333333333  |
# +-------------------+-----+---------------------+
# | colegio_genero(2) | ... | 0.3333333333333333  |
# +-------------------+-----+---------------------+
# | colegio_genero(3) | ... | 0.3333333333333333  |
# +-------------------+-----+---------------------+
# +-----------------------------+-----+--------------------------------+
# | colegio_privado             | ... | colegio_privado(1)             |
# +-----------------------------+-----+--------------------------------+
# | madre_educacion             | ... | madre_educacion(10)            |
# +-----------------------------+-----+--------------------------------+
# | presentacion_mcpio_distinto | ... | presentacion_mcpio_distinto(1) |
# +-----------------------------+-----+--------------------------------+
# | puntaje                     | ... | puntaje(10)                    |
# +-----------------------------+-----+--------------------------------+
# | colegio_jornada(1)          | ... | 0.0                            |
# +-----------------------------+-----+--------------------------------+
# | colegio_jornada(2)          | ... | 0.0                            |
# +-----------------------------+-----+--------------------------------+
# | colegio_jornada(3)          | ... | 0.0                            |
# +-----------------------------+-----+--------------------------------+
# | colegio_jornada(4)          | ... | 0.0                            |
# +-----------------------------+-----+--------------------------------+
# | colegio_jornada(5)          | ... | 1.0                            |
# +-----------------------------+-----+--------------------------------+
# | colegio_jornada(6)          | ... | 0.0                            |
# +-----------------------------+-----+--------------------------------+
# +----------------------+-----+---------------------+
# | colegio_genero       | ... | colegio_genero(3)   |
# +----------------------+-----+---------------------+
# | colegio_privado      | ... | colegio_privado(1)  |
# +----------------------+-----+---------------------+
# | madre_educacion      | ... | madre_educacion(10) |
# +----------------------+-----+---------------------+
# | puntaje              | ... | puntaje(10)         |
# +----------------------+-----+---------------------+
# | estudiante_genero(0) | ... | 0.8888888888888888  |
# +----------------------+-----+---------------------+
# | estudiante_genero(1) | ... | 0.1111111111111111  |
# +----------------------+-----+---------------------+
# +--------------------+-----+----------------------+
# | madre_educacion    | ... | madre_educacion(10)  |
# +--------------------+-----+----------------------+
# | padre_educacion    | ... | padre_educacion(10)  |
# +--------------------+-----+----------------------+
# | familia_estrato(1) | ... | 0.026454378444580526 |
# +--------------------+-----+----------------------+
# | familia_estrato(2) | ... | 0.08950398040416412  |
# +--------------------+-----+----------------------+
# | familia_estrato(3) | ... | 0.23630128597672995  |
# +--------------------+-----+----------------------+
# | familia_estrato(4) | ... | 0.28186160440906305  |
# +--------------------+-----+----------------------+
# | familia_estrato(5) | ... | 0.190789957134109    |
# +--------------------+-----+----------------------+
# | familia_estrato(6) | ... | 0.17508879363135335  |
# +--------------------+-----+----------------------+
# +---------------------+-----+-----------------------+
# | padre_educacion     | ... | padre_educacion(10)   |
# +---------------------+-----+-----------------------+
# | madre_educacion(1)  | ... | 0.0011822730692525407 |
# +---------------------+-----+-----------------------+
# | madre_educacion(2)  | ... | 0.004526075689360737  |
# +---------------------+-----+-----------------------+
# | madre_educacion(3)  | ... | 0.004848513799156884  |
# +---------------------+-----+-----------------------+
# | madre_educacion(4)  | ... | 0.013697648590228931  |
# +---------------------+-----+-----------------------+
# | madre_educacion(5)  | ... | 0.06404576232728662   |
# +---------------------+-----+-----------------------+
# | madre_educacion(6)  | ... | 0.014127566069957128  |
# +---------------------+-----+-----------------------+
# | madre_educacion(7)  | ... | 0.0780658490273117    |
# +---------------------+-----+-----------------------+
# | madre_educacion(8)  | ... | 0.03841790367460023   |
# +---------------------+-----+-----------------------+
# | madre_educacion(9)  | ... | 0.29355004358885556   |
# +---------------------+-----+-----------------------+
# | madre_educacion(10) | ... | 0.48753836416398966   |
# +---------------------+-----+-----------------------+
# +---------------------+-----------+
# | padre_educacion(1)  | 0.0408053 |
# +---------------------+-----------+
# | padre_educacion(2)  | 0.18912   |
# +---------------------+-----------+
# | padre_educacion(3)  | 0.130179  |
# +---------------------+-----------+
# | padre_educacion(4)  | 0.148511  |
# +---------------------+-----------+
# | padre_educacion(5)  | 0.25493   |
# +---------------------+-----------+
# | padre_educacion(6)  | 0.0213476 |
# +---------------------+-----------+
# | padre_educacion(7)  | 0.069116  |
# +---------------------+-----------+
# | padre_educacion(8)  | 0.0190933 |
# +---------------------+-----------+
# | padre_educacion(9)  | 0.101492  |
# +---------------------+-----------+
# | padre_educacion(10) | 0.0254059 |
# +---------------------+-----------+
# +-----------------+-----+-----------------------+
# | familia_estrato | ... | familia_estrato(6)    |
# +-----------------+-----+-----------------------+
# | internet        | ... | internet(1)           |
# +-----------------+-----+-----------------------+
# | madre_educacion | ... | madre_educacion(10)   |
# +-----------------+-----+-----------------------+
# | padre_educacion | ... | padre_educacion(10)   |
# +-----------------+-----+-----------------------+
# | computador(0)   | ... | 0.0021026072329688814 |
# +-----------------+-----+-----------------------+
# | computador(1)   | ... | 0.9978973927670312    |
# +-----------------+-----+-----------------------+
# +-----------------+-----+---------------------+
# | familia_estrato | ... | familia_estrato(6)  |
# +-----------------+-----+---------------------+
# | madre_educacion | ... | madre_educacion(10) |
# +-----------------+-----+---------------------+
# | padre_educacion | ... | padre_educacion(10) |
# +-----------------+-----+---------------------+
# | internet(0)     | ... | 0.00195858981533296 |
# +-----------------+-----+---------------------+
# | internet(1)     | ... | 0.9980414101846671  |
# +-----------------+-----+---------------------+
# +-----------------+-----+-----------------------+
# | computador      | ... | computador(1)         |
# +-----------------+-----+-----------------------+
# | familia_estrato | ... | familia_estrato(6)    |
# +-----------------+-----+-----------------------+
# | internet        | ... | internet(1)           |
# +-----------------+-----+-----------------------+
# | madre_educacion | ... | madre_educacion(10)   |
# +-----------------+-----+-----------------------+
# | puntaje(1)      | ... | 0.0                   |
# +-----------------+-----+-----------------------+
# | puntaje(2)      | ... | 0.0                   |
# +-----------------+-----+-----------------------+
# | puntaje(3)      | ... | 0.0004302463160159191 |
# +-----------------+-----+-----------------------+
# | puntaje(4)      | ... | 0.0040873400021512315 |
# +-----------------+-----+-----------------------+
# | puntaje(5)      | ... | 0.013230074217489512  |
# +-----------------+-----+-----------------------+
# | puntaje(6)      | ... | 0.08379047004410024   |
# +-----------------+-----+-----------------------+
# | puntaje(7)      | ... | 0.3732386791438098    |
# +-----------------+-----+-----------------------+
# | puntaje(8)      | ... | 0.4345487791760783    |
# +-----------------+-----+-----------------------+
# | puntaje(9)      | ... | 0.08690975583521567   |
# +-----------------+-----+-----------------------+
# | puntaje(10)     | ... | 0.003764655265139292  |
# +-----------------+-----+-----------------------+
# +---------------------------+-----+---------------------+
# | colegio_privado           | ... | colegio_privado(1)  |
# +---------------------------+-----+---------------------+
# | colegio_rural             | ... | colegio_rural(1)    |
# +---------------------------+-----+---------------------+
# | familia_estrato           | ... | familia_estrato(6)  |
# +---------------------------+-----+---------------------+
# | internet                  | ... | internet(1)         |
# +---------------------------+-----+---------------------+
# | colegio_mcpio_distinto(0) | ... | 0.5646321224414531  |
# +---------------------------+-----+---------------------+
# | colegio_mcpio_distinto(1) | ... | 0.43536787755854695 |
# +---------------------------+-----+---------------------+
# +--------------------------------+-----+---------------------------+
# | colegio_mcpio_distinto         | ... | colegio_mcpio_distinto(1) |
# +--------------------------------+-----+---------------------------+
# | colegio_privado                | ... | colegio_privado(1)        |
# +--------------------------------+-----+---------------------------+
# | colegio_rural                  | ... | colegio_rural(1)          |
# +--------------------------------+-----+---------------------------+
# | internet                       | ... | internet(1)               |
# +--------------------------------+-----+---------------------------+
# | presentacion_mcpio_distinto(0) | ... | 0.8008165188034859        |
# +--------------------------------+-----+---------------------------+
# | presentacion_mcpio_distinto(1) | ... | 0.1991834811965141        |
# +--------------------------------+-----+---------------------------+

# %% [markdown]
# ### Guardar Modelo

# %%
writer = BIFWriter(model)
writer.write_bif('../Models/Estructura_Puntaje_BIC.bif')
