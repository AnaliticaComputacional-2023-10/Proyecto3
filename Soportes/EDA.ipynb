# %% [markdown]
# # Proyecto 3
#
# **Tema:** Resultados Saber 11
#
#
#
# |     Nombres      |      Apellidos       |     Login     |  Codigo   |
# | :--------------: | :------------------: | :-----------: | :-------: |
# |     Santiago     | Gonzalez Montealegre | s.gonzalez35  | 202012274 |
# | Juliana Carolina |  Cardenas Barragan   | jc.cardenasb1 | 202011683 |

# %% [markdown]
# ## Análisis Exploratorio de Datos
# ### Análisis Univariado

# %% [markdown]
# ## Librerías Requeridas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carga de Datos

# %%
df = pd.read_csv('../Data/Transformed/Clean.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3295965 entries, 0 to 3295964
# Data columns (total 20 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   cole_area_ubicacion          object
#  1   cole_bilingue                object
#  2   cole_calendario              object
#  3   cole_naturaleza              object
#  4   cole_genero                  object
#  5   cole_jornada                 object
#  6   cole_cod_depto_ubicacion     int64
#  7   cole_cod_mcpio_ubicacion     int64
#  8   estu_cod_depto_presentacion  int64
#  9   estu_cod_mcpio_presentacion  int64
#  10  estu_cod_reside_depto        int64
#  11  estu_cod_reside_mcpio        int64
#  12  estu_genero                  object
#  13  fami_estratovivienda         object
#  14  fami_educacionmadre          object
#  15  fami_educacionpadre          object
#  16  fami_personashogar           object
#  17  fami_tienecomputador         object
# ...

# %%
df.head()
# Out:
#   cole_area_ubicacion cole_bilingue cole_calendario cole_naturaleza  \
# 0              URBANO             N               A         OFICIAL
# 1              URBANO             N               A         OFICIAL
# 2              URBANO             N               A         OFICIAL
# 3               RURAL             N               A      NO OFICIAL
# 4              URBANO             N               A         OFICIAL
#
#   cole_genero cole_jornada  cole_cod_depto_ubicacion  \
# 0       MIXTO       MAÑANA                        13
# 1       MIXTO       MAÑANA                        70
# 2       MIXTO       MAÑANA                        70
# 3   MASCULINO     COMPLETA                        11
# 4       MIXTO       MAÑANA                        25
#
#    cole_cod_mcpio_ubicacion  estu_cod_depto_presentacion  \
# 0                     13001                           13
# 1                     70523                           70
# 2                     70523                           70
# ...

# %%
numerical = ['punt_global']

categorical = [
    'cole_area_ubicacion',
    'cole_bilingue', 
    'cole_calendario', 
    'cole_naturaleza',
    'cole_genero',
    'cole_jornada',
    # 'cole_cod_depto_ubicacion', 
    # 'cole_cod_mcpio_ubicacion',       
    # 'estu_cod_depto_presentacion',
    # 'estu_cod_mcpio_presentacion',   
    # 'estu_cod_reside_depto',
    # 'estu_cod_reside_mcpio', 
    'estu_genero',    
    'fami_estratovivienda', 
    'fami_educacionmadre', 
    'fami_educacionpadre',   
    # 'fami_personashogar',
    'fami_tienecomputador', 
    'fami_tieneinternet'
]
total = categorical + numerical

# %%
len(categorical)
# Out:
# 12

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(10, 15))

data = df[total].copy()

# contador = 0
for ax, column in zip(axes.flatten(), data.columns):
    
    # contador += 1
    
    # if contador == 1:
    #     sns.violinplot(data=data, x=column, y=data['punt_global'], ax=ax, palette='rainbow', inner='quartile')
        
    # if column == df.columns[-1]:
    #     ax.set_visible(False)
    #     continue
    # if contador in [20, 21]:
    #     ax.set_visible(False)
    #     continue
    # continue
    sns.violinplot(data=data, x=column, y=data['punt_global'], ax=ax, palette='rainbow', inner='quartile')
    # ax.set_title(column)
    
    # break
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {categorical[0]}')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\SGM\Documents\Analytics\Proyectos\Proyecto3\Soportes\EDA.ipynb Cell 11 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/SGM/Documents/Analytics/Proyectos/Proyecto3/Soportes/EDA.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> # contador = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/SGM/Documents/Analytics/Proyectos/Proyecto3/Soportes/EDA.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> for ax, column in zip(axes.flatten(), data.columns):
#       <a href='vscode-notebook-cell:/c%3A/Users/SGM/Documents/Analytics/Proyectos/Proyecto3/Soportes/EDA.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/SGM/Documents/Analytics/Proyectos/Proyecto3/Soportes/EDA.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a>     # contador += 1
#    (...)
# ...

# %%
sns.violinplot(data=df, x=column, y=df['punt_global'], ax=ax, palette='rainbow', inner='quartile')

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(15, 15))

data = df[total].copy()

# contador = 0
for ax, column in zip(axes.flatten(), categorical):
    
    # contador += 1
    
    # if contador == 1:
    #     sns.violinplot(data=data, x=column, y=data['punt_global'], ax=ax, palette='rainbow', inner='quartile')
        
    # if column == df.columns[-1]:
    #     ax.set_visible(False)
    #     continue
    # if contador in [20, 21]:
    #     ax.set_visible(False)
    #     continue
    # continue
    sns.violinplot(data=data, x=column, y=data['punt_global'], ax=ax, palette='rainbow', inner='quartile')
    # ax.set_title(column)
    
    # break
    
fig.subplots_adjust(hspace=0.7, wspace=0.3)
fig.suptitle(f'Violin Plot Grouped by {categorical[0]}')

plt.tight_layout()
plt.show()

# %%
df['punt_global'].hist()
# Out:
# <AxesSubplot: >

# %%
sns.histplot(data=df, x='punt_global')
# Out:
# <AxesSubplot: xlabel='punt_global', ylabel='Count'>
